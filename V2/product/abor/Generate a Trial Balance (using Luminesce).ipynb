# %% [markdown]
# # Running an ABOR using Luminesce
#
# In this notebook, we setup LUSID to run a Trial Balance on an Equity/Bond portfolio.

# %% [markdown]
# ## Preliminary setup
#
# Before we start the portfolio and ABOR setup, we need to create a Recipe and some Transaction Types in LUSID.

# %%
# !pip3 install -U lusid-sdk

# %%
# Import general modules
import logging
import lumipy as lm
import lusid
import lusid.models as models
import os
import pandas as pd
import numpy as np

from lusidjam import RefreshingToken

from lusid.extensions import (
    SyncApiClientFactory,
    ArgsConfigurationLoader,
    EnvironmentVariablesConfigurationLoader,
    SecretsFileConfigurationLoader
)

# Create loggers
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

scope = "tb-example-scope"

def create_recipe(api_factory):
    recipes_api = api_factory.build(lusid.api.ConfigurationRecipeApi)

    recipe_code = "marketValue"

    configuration_recipe = models.ConfigurationRecipe(
        scope=scope,
        code=recipe_code,
        market=models.MarketContext(
            market_rules=[
                models.MarketDataKeyRule(
                    key="Quote.ClientInternal.*",
                    supplier="Lusid",
                    data_scope=scope,
                    quote_type="Price",
                    field="mid",
                    quote_interval="100D.0D",
                ),
                models.MarketDataKeyRule(
                    key="FX.*.*",
                    supplier="Lusid",
                    data_scope=scope,
                    quote_type="Rate",
                    field="mid",
                    quote_interval="100D.0D",
                ),
            ],
            suppliers=models.MarketContextSuppliers(
                commodity="Client",
                credit="Client",
                equity="Client",
                fx="Client",
                rates="Client",
            ),
            options=models.MarketOptions(
                default_supplier="Lusid",
                default_instrument_code_type="ClientInternal",
                default_scope=scope,
                attempt_to_infer_missing_fx=True,
            ),
        ),
        pricing=models.PricingContext(
            model_rules=[
                models.VendorModelRule(
                    supplier="Lusid", model_name="SimpleStatic", instrument_type="Bond"
                )
            ]
        ),
    )

    upsert_configuration_recipe_response = recipes_api.upsert_configuration_recipe(
        upsert_recipe_request=models.UpsertRecipeRequest(
            configuration_recipe=configuration_recipe
        )
    )
    
    return upsert_configuration_recipe_response


def create_txn_types(api_factory):
    transaction_configuration = api_factory.build(lusid.api.TransactionConfigurationApi)
    
    transaction_configuration.set_side_definitions(
        scope=scope,
        sides_definition_request=[
            models.SidesDefinitionRequest(
                side="Side1",
                side_request=models.SideDefinitionRequest(
                    security="Txn:LusidInstrumentId",
                    currency="Txn:TradeCurrency",
                    rate="Txn:TradeToPortfolioRate",
                    units="Txn:Units",
                    amount="Txn:TradeAmount"
                )
            ),
            models.SidesDefinitionRequest(
                side="Side2",
                side_request=models.SideDefinitionRequest(
                    security="Txn:SettleCcy",
                    currency="Txn:SettlementCurrency",
                    rate="SettledToPortfolioRate",
                    units="Txn:TotalConsideration",
                    amount="Txn:TotalConsideration"
                )
            )
        ]
    )

    response = transaction_configuration.set_transaction_type_source(
        source="abor",
        scope=scope,
        transaction_type_request=[
            models.TransactionTypeRequest(
                aliases=[
                    models.TransactionConfigurationTypeAlias(
                        type="FundsIn",
                        description="Deposit New Funds",
                        transaction_class="CashTransfers",
                        transaction_group="abor",
                        transaction_roles="Longer"
                    )
                ],
                movements=[
                    models.TransactionConfigurationMovementDataRequest(
                        name="Subscription",
                        movement_types="CashReceivable",
                        side="Side1",
                        direction=1,
                        movement_options=[],
                    ),
                    models.TransactionConfigurationMovementDataRequest(
                        name="Subscription",
                        movement_types="Capital",
                        side="Side1",
                        direction=1,
                        movement_options=[],
                    )
                ],
            ),
            models.TransactionTypeRequest(
                aliases=[
                    models.TransactionConfigurationTypeAlias(
                        type="FundsOut",
                        description="Deposit New Funds",
                        transaction_class="CashTransfers",
                        transaction_group="abor",
                        transaction_roles="Shorter",
                    )
                ],
                movements=[
                    models.TransactionConfigurationMovementDataRequest(
                        name="Redemption",
                        movement_types="CashReceivable",
                        side="Side1",
                        direction=-1,
                        movement_options=[],
                    ),
                    models.TransactionConfigurationMovementDataRequest(
                        name="Redemption",
                        movement_types="Capital",
                        side="Side1",
                        direction=-1,
                        movement_options=[],
                    )
                ],
            ),
            models.TransactionTypeRequest(
                aliases=[
                    models.TransactionConfigurationTypeAlias(
                        type="Buy",
                        description="Buy",
                        transaction_class="Buy",
                        transaction_group="abor",
                        transaction_roles="AllRoles",
                    )
                ],
                movements=[
                    models.TransactionConfigurationMovementDataRequest(
                        name="Bought",
                        movement_types="StockMovement",
                        side="Side1",
                        direction=1,
                        movement_options=[],
                    ),
                    models.TransactionConfigurationMovementDataRequest(
                        name="CashInvested",
                        movement_types="CashCommitment",
                        side="Side2",
                        direction=-1,
                        movement_options=[],
                    ),
                ],
            ),
            models.TransactionTypeRequest(
                aliases=[
                    models.TransactionConfigurationTypeAlias(
                        type="Sell",
                        description="Sell",
                        transaction_class="Sell",
                        transaction_group="abor",
                        transaction_roles="AllRoles",
                    )
                ],
                movements=[
                    models.TransactionConfigurationMovementDataRequest(
                        name="Sale",
                        movement_types="StockMovement",
                        side="Side1",
                        direction=-1,
                        movement_options=[],
                    ),
                    models.TransactionConfigurationMovementDataRequest(
                        name="CashProceeds",
                        movement_types="CashCommitment",
                        side="Side2",
                        direction=1,
                        movement_options=[],
                    ),
                ],
            ),
            models.TransactionTypeRequest(
                aliases=[
                    models.TransactionConfigurationTypeAlias(
                        type="FxSpotBuy",
                        description="FxSpotBuy",
                        transaction_class="FxSpotBuy",
                        transaction_group="abor",
                        transaction_roles="AllRoles",
                    )
                ],
                movements=[
                    models.TransactionConfigurationMovementDataRequest(
                        name="FxSpotBuyLeg",
                        movement_types="CashCommitment",
                        side="Side1",
                        direction=1,
                        movement_options=[],
                    ),
                    models.TransactionConfigurationMovementDataRequest(
                        name="FxSpotSellLeg",
                        movement_types="CashCommitment",
                        side="Side2",
                        direction=-1,
                        movement_options=[],
                    ),
                ],
            ),
        ],
    )
    
    return response

token = RefreshingToken()

try:
    # Authenticate to SDK
    # Run the Notebook in Jupyterhub for your LUSID domain and authenticate automatically
    secrets_path = os.getenv("FBN_SECRETS_PATH")
    # Run the Notebook locally using a secrets file (see https://support.lusid.com/docs/how-do-i-use-an-api-access-token-with-the-lusid-sdk)
    if secrets_path is None:
        secrets_path = os.path.join(os.path.dirname(os.getcwd()), "secrets.json")
        print()

    # Initiate an API Factory which is the client side object for interacting with LUSID APIs
    config_loaders=[
        ArgsConfigurationLoader(access_token = token, app_name = "LusidJupyterNotebook"),
        EnvironmentVariablesConfigurationLoader(),
        SecretsFileConfigurationLoader(secrets_path)]
    api_factory = SyncApiClientFactory(config_loaders=config_loaders)

    print([api for api in dir(lusid.api) if "Api" in api])
except Exception as e:
    print(e)

atlas = lm.get_atlas(access_token=token, api_url=lumi_url)

create_recipe(api_factory)
create_txn_types(api_factory)

# %% [markdown]
# ## A quick word on the luminesce magic command...
#
# You can run the cells below directly in LUSID's JupyterHub.
#
# The `%%luminesce` command is a magic command which passes the cell query string to Lumipy,
# which then returns a DataFrame.
#
# Under the hood, when you run a cell with the `%%luminesce` command, Jupyter will pass the cell contents to this function:
#
# ```python
#
# import os
# from IPython.core.magic import (register_line_cell_magic)
# from lumipy.client import Client
#
# @register_line_cell_magic
# def luminesce(line, cell=None):
#     query = cell if cell is not None else line
#
#     try:
#         lm_client = Client(token=token, api_url=lumi_url)
#     except TypeError:
#         # Attempt to use V2 SDK syntax if V1 syntax fails.
#         # This gives V2 SDK support for luminesce magic
#         lm_client = Client(access_token=token, api_url=lumi_url)
#
#     df = lm_client.query_and_fetch(query)
#
#     return df
#
# ```

# %% [markdown]
# ## Create a portfolio
#
# First we create a portfolio to hold our Equity/Bond transactions and positions.

# %%
# %%luminesce
#
# /*
#
# ------------------------------
# Create a Transaction portfolio
# ------------------------------
#
# In this snippet we load a Transaction portfolio into LUSID.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# */
#
# -- Step 1: Define the portfolio details
#
# @@scope = select 'tb-example-scope';
# @@portfolioCode = select 'tbAborPortfolio';
# @@writeAction = select 'Upsert';
#
# @createPortfolio = select 'Transaction' as PortfolioType,
# @@scope as PortfolioScope,
# @@portfolioCode as PortfolioCode,
# @@scope  as InstrumentScopes,
# @@portfolioCode as DisplayName,
# @@portfolioCode  as Description,
# #2000-01-01# as Created,
# '' as SubHoldingKeys,
# 'GBP' as BaseCurrency,
# @@scope as TransactionTypeScope,
# @@writeAction as WriteAction
# ;
#
# -- Step 2: Load portfolio into LUSID
#
# select *
# from Lusid.Portfolio.Writer
# where ToWrite = @createPortfolio;
# Out:
#      PortfolioScope    PortfolioCode PortfolioType BaseCurrency  \
# 0  tb-example-scope  tbAborPortfolio   Transaction          GBP
#
#        DisplayName      Description  ParentPortfolioScope  \
# 0  tbAborPortfolio  tbAborPortfolio                   NaN
#
#    ParentPortfolioCode  CorporateActionSourceScope  CorporateActionSourceId  \
# 0                  NaN                         NaN                      NaN
#
#    ... PfCurrAndAmountPropUnit  NonExistingProp PfTimeVarStrArray WriteAction  \
# 0  ...                     NaN              NaN               NaN      Insert
#
#   StagedModificationsCountPending StagedModificationsIdsPreviewed  \
# 0                               0                             NaN
#
#                  WriteAsAt  WriteErrorCode  WriteError  WriteErrorDetail
# 0  2025-01-08 11:14:51.077               0         NaN               NaN
#
# [1 rows x 38 columns]

# %% [markdown]
# ## Create equity instruments
#
# Create some equity instruments using the LUSID `Equity` model.

# %%
# %%luminesce
#
# /*
#
# ------------------------------
# Create some equity instruments
# ------------------------------
#
# In this snippet we create some Equity instruments into LUSID.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# */
#
# -- Step 1: Define the equity instruments
#
# @@scope = select 'tb-example-scope';
#
# @instrumentsData=
# values
# ('Tesco', 'FBNABOR001', 'GBP'),
# ('Sainsburys', 'FBNABOR002', 'GBP'),
# ('Walmart', 'FBNABOR003', 'USD'),
# ('Wholefoods', 'FBNABOR004', 'USD'),
# ('Waitrose', 'FBNABOR005', 'GBP');
#
# @instrumentsForUpload = select
# column1 as DisplayName,
# column2 as ClientInternal,
# column3 as DomCcy,
# @@scope as Scope
# from @instrumentsData;
#
# -- Step 2: Upload the transformed data into LUSID
#
# select *
# from Lusid.Instrument.Equity.Writer
# where ToWrite = @instrumentsForUpload;
# Out:
#                  WriteAsAt  WriteErrorCode  WriteError  WriteErrorDetail  \
# 0  2025-01-08 11:14:53.085               0         NaN               NaN
# 1  2025-01-08 11:14:53.085               0         NaN               NaN
# 2  2025-01-08 11:14:53.085               0         NaN               NaN
# 3  2025-01-08 11:14:53.085               0         NaN               NaN
# 4  2025-01-08 11:14:53.085               0         NaN               NaN
#
#   WriteAction LusidInstrumentId  Figi ClientInternal  QuotePermId  EdiKey  \
# 0      Upsert     LUID_000CVCK8   NaN     FBNABOR005          NaN     NaN
# 1      Upsert     LUID_000CVCK9   NaN     FBNABOR004          NaN     NaN
# 2      Upsert     LUID_000CVCKA   NaN     FBNABOR001          NaN     NaN
# 3      Upsert     LUID_000CVCKB   NaN     FBNABOR002          NaN     NaN
# 4      Upsert     LUID_000CVCKC   NaN     FBNABOR003          NaN     NaN
#
#    ...  IssuerId  SecurityId  CountryOfIncorporation  PrimaryCurrency  \
# 0  ...       NaN         NaN                     NaN              NaN
# 1  ...       NaN         NaN                     NaN              NaN
# 2  ...       NaN         NaN                     NaN              NaN
# 3  ...       NaN         NaN                     NaN              NaN
# 4  ...       NaN         NaN                     NaN              NaN
#
#    PrimaryExchange  NaicsCode  LegalEntityId  IssuerName  ParValue  Exchange
# 0              NaN        NaN            NaN         NaN       NaN       NaN
# 1              NaN        NaN            NaN         NaN       NaN       NaN
# 2              NaN        NaN            NaN         NaN       NaN       NaN
# 3              NaN        NaN            NaN         NaN       NaN       NaN
# 4              NaN        NaN            NaN         NaN       NaN       NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Create bond instruments
#
# Create a `Bond` instrument using the Bond model. Here we create some simple UK and US government bonds.

# %%
# %%luminesce
#
# /*
#
# -----------------------
# Create Bond instruments
# -----------------------
#
# In this snippet we create Bond instruments.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# */
#
# @@scope = select 'tb-example-scope';
#
# -- Step 1: Define the bond instruments
#
# @bondsData=
# values
# ('US BOND 4% 01/01/2033', 'FBNBND001',  #2023-01-01#,  0.04, 'USD', '1Y', 'ActAct', #2033-01-01#),
# ('US BOND 7% 01/01/2028', 'FBNBND002',  #2023-01-01#,  0.07, 'USD', '1Y', 'ActAct', #2028-01-01#),
# ('UK BOND 3% 01/01/2033', 'FBNBND003',  #2023-01-01#,  0.03, 'GBP', '1Y', 'ActAct', #2033-01-01#),
# ('UK BOND 8% 01/01/2028', 'FBNBND004',  #2023-01-01#,  0.08, 'GBP', '1Y', 'ActAct', #2028-01-01#);
#
#
# @bondsDataForUpload =
# select
# Column1 as DisplayName,
# column2 as ClientInternal,
# column3 as StartDate,
# column4 as CouponRate,
# column5 as DomCcy,
# column5 as FlowConventionsCurrency,
# column6 as FlowConventionsPaymentFrequency,
# column7 as FlowConventionsDayCountConvention,
# 'MF' as FlowConventionsRollConvention,
# column5 as FlowConventionsPaymentCalendars,
# column5 as FlowConventionsResetCalendars,
# 0 as FlowConventionsSettleDays,
# 0 as FlowConventionsResetDays,
# 1 as Principal,
# column8 as MaturityDate,
# @@scope as Scope
# from @bondsData;
#
# -- Step 2: Upload the transformed data into LUSID
#
# select *
# from Lusid.Instrument.Bond.Writer
# where ToWrite = @bondsDataForUpload;
# Out:
#                  WriteAsAt  WriteErrorCode  WriteError  WriteErrorDetail  \
# 0  2025-01-08 11:14:54.651               0         NaN               NaN
# 1  2025-01-08 11:14:54.651               0         NaN               NaN
# 2  2025-01-08 11:14:54.651               0         NaN               NaN
# 3  2025-01-08 11:14:54.651               0         NaN               NaN
#
#   WriteAction LusidInstrumentId  Figi ClientInternal  QuotePermId  EdiKey  \
# 0      Upsert     LUID_000CVCKD   NaN      FBNBND004          NaN     NaN
# 1      Upsert     LUID_000CVCKE   NaN      FBNBND001          NaN     NaN
# 2      Upsert     LUID_000CVCKF   NaN      FBNBND002          NaN     NaN
# 3      Upsert     LUID_000CVCKG   NaN      FBNBND003          NaN     NaN
#
#    ...  IssuerId  SecurityId  CountryOfIncorporation  PrimaryCurrency  \
# 0  ...       NaN         NaN                     NaN              NaN
# 1  ...       NaN         NaN                     NaN              NaN
# 2  ...       NaN         NaN                     NaN              NaN
# 3  ...       NaN         NaN                     NaN              NaN
#
#    PrimaryExchange  NaicsCode  LegalEntityId  IssuerName  ParValue  Exchange
# 0              NaN        NaN            NaN         NaN       NaN       NaN
# 1              NaN        NaN            NaN         NaN       NaN       NaN
# 2              NaN        NaN            NaN         NaN       NaN       NaN
# 3              NaN        NaN            NaN         NaN       NaN       NaN
#
# [4 rows x 101 columns]

# %% [markdown]
# ## Create instrument properties
#
# Create some instrument properties which we'll assign to the instruments. We create properties for:
#
# * Sector
# * Asset Class
# * Internal rating
#
# These properties are later used in Posting Rules for the ABOR.

# %%
# %%luminesce
#
# /*
#
# ----------------------------
# Create instrument properties
# ----------------------------
#
# In this snippet we create some instrument properties.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# */
#
# @@scope = select 'tb-example-scope';
#
# -- Step 1: Define the property definitions
#
# @newProperties =
# values
# ('Instrument', @@scope, 'Sector', 'string'),
# ('Instrument', @@scope, 'AssetClass', 'string'),
# ('Instrument', @@scope, 'InternalRating', 'number');
#
# @propertyDefinitions =
# select
# Column1 as [Domain],
# Column2 as [PropertyScope],
# Column3 as [PropertyCode],
# Column3 as [DisplayName],
# 'Property' as [ConstraintStyle],
# 'system' as [DataTypeScope],
# column4 as [DataTypeCode]
# from @newProperties;
#
# -- Step 2: Load property definitions
#
# select *
# from Lusid.Property.Definition.Writer
# where ToWrite = @propertyDefinitions;
# Out:
#        Domain     PropertyScope    PropertyCode     DisplayName  Description  \
# 0  Instrument  tb-example-scope          Sector          Sector          NaN
# 1  Instrument  tb-example-scope      AssetClass      AssetClass          NaN
# 2  Instrument  tb-example-scope  InternalRating  InternalRating          NaN
#
#     Lifetime ConstraintStyle  Required  DerivationFormula  CollectionType  \
# 0  Perpetual        Property     False                NaN             NaN
# 1  Perpetual        Property     False                NaN             NaN
# 2  Perpetual        Property     False                NaN             NaN
#
#    ...  PropDefTimeVarStrColl  DataTypeScope  DataTypeCode  \
# 0  ...                    NaN         system        string
# 1  ...                    NaN         system        string
# 2  ...                    NaN         system        number
#
#    StagedModificationsCountPending  StagedModificationsIdsPreviewed  \
# 0                                0                              NaN
# 1                                0                              NaN
# 2                                0                              NaN
#
#    WriteAction                WriteAsAt WriteErrorCode  WriteError  \
# 0       Insert  2025-01-08 11:14:56.935              0         NaN
# 1       Insert  2025-01-08 11:14:57.533              0         NaN
# 2       Insert  2025-01-08 11:14:57.769              0         NaN
#
#    WriteErrorDetail
# 0               NaN
# 1               NaN
# 2               NaN
#
# [3 rows x 25 columns]

# %% [markdown]
# ##  Assign properties to instrument
#
# Then assign properties to each of the instruments.

# %%
# %%luminesce
#
# /*
#
# --------------------------------
# Assign properties to instruments
# --------------------------------
#
# In this snippet we assign properties to instruments.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Setup the property definitions referenced below
#     2. Setup the instruments referenced below
#
# */
#
# @@scope = select 'tb-example-scope';
#
# -- Step 1: Define the property definitions
#
# @newProperties =
# values
#
# -- Sectors
# ('FBNABOR001', @@scope, 'Sector', 'Consumer'),
# ('FBNABOR002', @@scope, 'Sector', 'Consumer'),
# ('FBNABOR003', @@scope, 'Sector', 'Consumer'),
# ('FBNABOR004', @@scope, 'Sector', 'Consumer'),
# ('FBNABOR005', @@scope, 'Sector', 'Consumer'),
# ('FBNBND001', @@scope, 'Sector', 'Government'),
# ('FBNBND002', @@scope, 'Sector', 'Government'),
# ('FBNBND003', @@scope, 'Sector', 'Government'),
# ('FBNBND004', @@scope, 'Sector', 'Government'),
#
# -- Country
# ('FBNABOR001', @@scope, 'AssetClass', 'Common Stock'),
# ('FBNABOR002', @@scope, 'AssetClass', 'Common Stock'),
# ('FBNABOR003', @@scope, 'AssetClass', 'Common Stock'),
# ('FBNABOR004', @@scope, 'AssetClass', 'Common Stock'),
# ('FBNABOR005', @@scope, 'AssetClass', 'Common Stock'),
# ('FBNBND001', @@scope, 'AssetClass', 'Government Bond'),
# ('FBNBND002', @@scope, 'AssetClass', 'Government Bond'),
# ('FBNBND003', @@scope, 'AssetClass', 'Government Bond'),
# ('FBNBND004', @@scope, 'AssetClass', 'Government Bond'),
#
# -- Internal ratings
# ('FBNABOR001', @@scope, 'InternalRating', 8),
# ('FBNABOR002', @@scope, 'InternalRating', 8),
# ('FBNABOR003', @@scope, 'InternalRating', 9),
# ('FBNABOR004', @@scope, 'InternalRating', 7),
# ('FBNABOR005', @@scope, 'InternalRating', 7),
# ('FBNBND001', @@scope, 'InternalRating', 8),
# ('FBNBND002', @@scope, 'InternalRating', 8),
# ('FBNBND003', @@scope, 'InternalRating', 6),
# ('FBNBND004', @@scope, 'InternalRating', 7);
#
# @instProperties =
# select
# column1 as EntityId,
# 'ClientInternal' as EntityIdType,
# 'Instrument' as Domain,
# Column2 as PropertyScope,
# Column3 as PropertyCode,
# Column4 as Value,
# @@scope as EntityScope
# from @newProperties;
#
# -- Upload the transformed data into LUSID
#
# select *
# from Lusid.Property.Writer
# where ToWrite = @instProperties
# limit 5;
# Out:
#        Domain    EntityIdType       EntityScope    EntityId     PropertyScope  \
# 0  Instrument  ClientInternal  tb-example-scope  FBNABOR001  tb-example-scope
# 1  Instrument  ClientInternal  tb-example-scope  FBNABOR001  tb-example-scope
# 2  Instrument  ClientInternal  tb-example-scope  FBNABOR001  tb-example-scope
# 3  Instrument  ClientInternal  tb-example-scope   FBNBND001  tb-example-scope
# 4  Instrument  ClientInternal  tb-example-scope   FBNBND001  tb-example-scope
#
#      PropertyCode            Value  Unit  EffectiveFrom  EffectiveUntil  \
# 0          Sector         Consumer   NaN            NaN             NaN
# 1      AssetClass     Common Stock   NaN            NaN             NaN
# 2  InternalRating                8   NaN            NaN             NaN
# 3          Sector       Government   NaN            NaN             NaN
# 4      AssetClass  Government Bond   NaN            NaN             NaN
#
#   WriteAction                WriteAsAt  WriteErrorCode  WriteError  \
# 0      Upsert  2025-01-08 11:14:58.905               0         NaN
# 1      Upsert  2025-01-08 11:14:58.905               0         NaN
# 2      Upsert  2025-01-08 11:14:58.905               0         NaN
# 3      Upsert  2025-01-08 11:14:58.905               0         NaN
# 4      Upsert  2025-01-08 11:14:58.905               0         NaN
#
#    WriteErrorDetail
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# ## Create transactions
#
# Create transactions on these instruments:
#
# * We create Buys and Sells to simulate the realised P&L
# * The transactions are in portfolio base and non-base currency to see impact of FX gain/loss

# %%
# %%luminesce
#
# /*
#
# ------------------
# Create transactions
# ------------------
#
# In this snippet we create some Transactions.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Setup a portfolio with scope/code per below
#     2. Setup Buy and Sell Transaction Types
#     3. Setup instruments with the ClientInternal instrument IDs referenced below
#
# */
#
#
# @@scope = select 'tb-example-scope';
# @@portfolioCode = select 'tbAborPortfolio';
#
# -- Step 1: Define some transactions
#
# @transactions =
# values
#
# -- Equity Transactions
# (@@scope, @@portfolioCode, 'txn_001', 'Buy', '2023-01-01', '2023-01-03', 1000, 10, 10000, 'GBP', 'FBNABOR001', 1),
# (@@scope, @@portfolioCode, 'txn_002', 'Buy', '2023-01-01', '2023-01-03', 2000, 12, 20000, 'GBP', 'FBNABOR002', 1),
# (@@scope, @@portfolioCode, 'txn_003', 'Buy', '2023-01-01', '2023-01-03', 3000, 13, 30000, 'USD', 'FBNABOR003', 0.8),
# (@@scope, @@portfolioCode, 'txn_004', 'Buy', '2023-01-01', '2023-01-03', 4000, 14, 40000, 'USD', 'FBNABOR004', 0.8),
# (@@scope, @@portfolioCode, 'txn_005', 'Buy', '2023-01-01', '2023-01-03', 5000, 15, 50000, 'GBP', 'FBNABOR005', 1),
# (@@scope, @@portfolioCode, 'txn_006', 'Sell', '2023-02-01', '2023-02-03', 1000, 21, 21000, 'GBP', 'FBNABOR001', 1),
# (@@scope, @@portfolioCode, 'txn_007', 'Sell', '2023-02-01', '2023-02-03', 1000, 22, 22000, 'GBP', 'FBNABOR002', 1),
# (@@scope, @@portfolioCode, 'txn_008', 'Sell', '2023-02-01', '2023-02-03', 1000, 23, 23000, 'USD', 'FBNABOR003', 0.78),
# (@@scope, @@portfolioCode, 'txn_009', 'Sell', '2023-02-01', '2023-02-03', 1000, 24, 24000, 'USD', 'FBNABOR004', 0.78),
# (@@scope, @@portfolioCode, 'txn_010', 'Sell', '2023-02-01', '2023-02-03', 1000, 25, 25000, 'GBP', 'FBNABOR005', 1),
#
# --Bond transactions
# (@@scope, @@portfolioCode, 'txn_011', 'Buy', '2023-01-01', '2023-01-03', 100000, 100, 100000, 'USD', 'FBNBND001', 0.8),
# (@@scope, @@portfolioCode, 'txn_012', 'Buy', '2023-01-01', '2023-01-03', 200000, 98, 200000, 'GBP', 'FBNBND003', 1),
# (@@scope, @@portfolioCode, 'txn_013', 'Sell', '2023-02-01', '2023-02-03', 50000, 100, 50000, 'USD', 'FBNBND001', 0.78),
# (@@scope, @@portfolioCode, 'txn_014', 'Sell', '2023-02-01', '2023-02-03', 100000, 102, 100000, 'GBP', 'FBNBND003', 1)
# ;
#
#
# -- Step 2: Load transactions into LUSID
#
# @createTransactions =
# select
# column1 as PortfolioScope,
# column2 as PortfolioCode,
# column3 as TxnId,
# column4 as Type,
# column5 as TransactionDate,
# column6 as SettlementDate,
# column7 as Units,
# column8 as TradePrice,
# column9 as TotalConsideration,
# column10 as SettlementCurrency,
# column11 as ClientInternal,
# column12 as TradeToPortfolioRate,
# 'abor' as Source
# from @transactions;
#
# -- Upload the transformed data into LUSID
#
# select *
# from Lusid.Portfolio.Txn.Writer
# where ToWrite = @createTransactions;
# Out:
#       PortfolioScope    PortfolioCode      DisplayName    TxnId  Type  \
# 0   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_001   Buy
# 1   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_002   Buy
# 2   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_003   Buy
# 3   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_004   Buy
# 4   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_005   Buy
# 5   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_006  Sell
# 6   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_007  Sell
# 7   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_008  Sell
# 8   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_009  Sell
# 9   tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_010  Sell
# 10  tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_011   Buy
# 11  tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_012   Buy
# 12  tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_013  Sell
# 13  tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_014  Sell
#
#    TransactionDate SettlementDate   Units  TradePrice TradePriceType  ...  \
# 0       2023-01-01     2023-01-03    1000          10          Price  ...
# 1       2023-01-01     2023-01-03    2000          12          Price  ...
# 2       2023-01-01     2023-01-03    3000          13          Price  ...
# 3       2023-01-01     2023-01-03    4000          14          Price  ...
# 4       2023-01-01     2023-01-03    5000          15          Price  ...
# 5       2023-02-01     2023-02-03    1000          21          Price  ...
# 6       2023-02-01     2023-02-03    1000          22          Price  ...
# 7       2023-02-01     2023-02-03    1000          23          Price  ...
# 8       2023-02-01     2023-02-03    1000          24          Price  ...
# 9       2023-02-01     2023-02-03    1000          25          Price  ...
# 10      2023-01-01     2023-01-03  100000         100          Price  ...
# 11      2023-01-01     2023-01-03  200000          98          Price  ...
# 12      2023-02-01     2023-02-03   50000         100          Price  ...
# 13      2023-02-01     2023-02-03  100000         102          Price  ...
#
#     TxnPctProp  TxnDerivedDateProp  TxnAmountProp TxnCurrencyProp  \
# 0          NaN                 NaN            NaN             NaN
# 1          NaN                 NaN            NaN             NaN
# 2          NaN                 NaN            NaN             NaN
# 3          NaN                 NaN            NaN             NaN
# 4          NaN                 NaN            NaN             NaN
# 5          NaN                 NaN            NaN             NaN
# 6          NaN                 NaN            NaN             NaN
# 7          NaN                 NaN            NaN             NaN
# 8          NaN                 NaN            NaN             NaN
# 9          NaN                 NaN            NaN             NaN
# 10         NaN                 NaN            NaN             NaN
# 11         NaN                 NaN            NaN             NaN
# 12         NaN                 NaN            NaN             NaN
# 13         NaN                 NaN            NaN             NaN
#
#     ShareClassShortCode WriteAction                WriteAsAt  WriteErrorCode  \
# 0                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 1                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 2                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 3                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 4                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 5                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 6                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 7                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 8                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 9                   NaN      Upsert  2025-01-08 11:15:00.385               0
# 10                  NaN      Upsert  2025-01-08 11:15:00.385               0
# 11                  NaN      Upsert  2025-01-08 11:15:00.385               0
# 12                  NaN      Upsert  2025-01-08 11:15:00.385               0
# 13                  NaN      Upsert  2025-01-08 11:15:00.385               0
#
#     WriteError  WriteErrorDetail
# 0          NaN               NaN
# 1          NaN               NaN
# 2          NaN               NaN
# 3          NaN               NaN
# 4          NaN               NaN
# 5          NaN               NaN
# 6          NaN               NaN
# 7          NaN               NaN
# 8          NaN               NaN
# 9          NaN               NaN
# 10         NaN               NaN
# 11         NaN               NaN
# 12         NaN               NaN
# 13         NaN               NaN
#
# [14 rows x 68 columns]

# %% [markdown]
# ## Upload fx and instrument prices
#
# In the following cells, we load fx and instrument prices. For the purposes of this notebook we simulate some real looking prices. You can of course replace these prices with your own "real" prices from your data vendor.
#
# In this section, we do some preliminary data wrangling with python but the quote upload ultimately happens via Luminesce/Lumipy like the other cells in this notebook.

# %%
start_date = "2023-01-01"
end_date = "2023-04-01"
provider = "Lusid"
field = "mid"

default_range = np.random.default_rng()

quote_provider_columns = [
    "QuoteEffectiveAt",
    "Unit",
    "Instrumentid",
    "InstrumentIdType",
    "QuoteType",
    "Provider",
    "Field",
    "QuoteScope",
    "ScaleFactor",
]

date_range = pd.date_range(start=start_date, end=end_date)

# %% [markdown]
# Simulate some GBP/USD and GBP/EUR rates for Q1 2023

# %%
for start_price, ccy_pair, scale_factor in [
    (1.2097, "GBP/USD", 1),
    (1.1300, "GBP/EUR", 1),
]:
    fx_quotes = [
        (
            date,
            ccy_pair[-3:],
            ccy_pair,
            "CurrencyPair",
            "Rate",
            provider,
            field,
            scope,
            scale_factor,
        )
        for date in date_range
    ]

    df = pd.DataFrame(fx_quotes, columns=quote_provider_columns)

    df["Value"] = default_range.normal(start_price, 0.02, len(date_range))

    atlas.lusid_instrument_quote_writer(to_write=lm.from_pandas(df)).select("*").go(
        quiet=True
    )

# %% [markdown]
# Simulate some Equity and Bond price for Q1 2023

# %%
for instrument_id, start_price, ccy, scale_factor, avg_change in [
    ("FBNABOR001", 31, "GBP", 1, 0.5),
    ("FBNABOR002", 32, "GBP", 1, 0.4),
    ("FBNABOR003", 33, "GBP", 1, 0.3),
    ("FBNABOR004", 34, "USD", 1, 0.6),
    ("FBNABOR005", 34, "GBP", 1, 0.5),
    ("FBNBND001", 105, "USD", 100, 0.18),
    ("FBNBND002", 105, "USD", 100, 0.14),
    ("FBNBND003", 107, "GBP", 100, 0.9),
    ("FBNBND004", 98, "GBP", 100, 0.12),
]:
    instrument_quotes = [
        (
            date,
            ccy,
            instrument_id,
            "ClientInternal",
            "Price",
            provider,
            field,
            scope,
            scale_factor,
        )
        for date in date_range
    ]

    df = pd.DataFrame(instrument_quotes, columns=quote_provider_columns)

    df["Value"] = default_range.normal(start_price, avg_change, len(date_range))

    atlas.lusid_instrument_quote_writer(to_write=lm.from_pandas(df)).select("*").go(
        quiet=True
    )

# %% [markdown]
# ## Create cash transactions
#
# Create some cash transactions:
#
# * Subscriptions
# * Redemptions
# * FxSpots

# %%
# %%luminesce
#
# /*
#
# ------------------
# Create transaction
# ------------------
#
# In this snippet we create some cash Transactions.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Setup a portfolio with scope/code per below
#     2. Setup FundsIn Transaction Types
#
# */
#
#
# @@scope = select 'tb-example-scope';
# @@portfolioCode = select 'tbAborPortfolio';
#
#
#
# /*
#     Step 1: Define some cash transactions
#
#     In the step below, we create a transaction type called AborFundsIn which is configured to create
#     Capital movements in the Journal Entry
#
# */
#
# @transactions =
# values
# (@@scope, @@portfolioCode, 'csh_001', 'FundsIn', '2023-01-01', '2023-01-03', 1000000, 1, 1000000, 'GBP', 'CCY_GBP', 1, 1),
# (@@scope, @@portfolioCode, 'csh_002', 'FundsIn', '2023-01-01', '2023-01-03', 1000000, 1, 1000000, 'USD', 'CCY_USD', 0.79, 1),
# (@@scope, @@portfolioCode, 'csh_003', 'FundsOut', '2023-02-01', '2023-02-03', 200000, 1, 200000, 'GBP', 'CCY_GBP', 1, 1),
# (@@scope, @@portfolioCode, 'csh_004', 'FundsOut', '2023-02-01', '2023-02-03', 200000, 1, 200000, 'USD', 'CCY_USD', 0.81, 1),
#
# --Fx Spots
# (@@scope, @@portfolioCode, 'txn_015', 'FxSpotBuy', '2023-02-15', '2023-02-17', 100000, 1, 80000, 'GBP', 'CCY_USD', 0.8, 0.8),
# (@@scope, @@portfolioCode, 'txn_016', 'FxSpotBuy', '2023-02-16', '2023-02-18', 50000, 1, 40000, 'GBP', 'CCY_USD', 0.8, 0.8)
# ;
#
#
# @createTransactions =
# select
# column1 as PortfolioScope,
# column2 as PortfolioCode,
# column3 as TxnId,
# column4 as Type,
# column5 as TransactionDate,
# column6 as SettlementDate,
# column7 as Units,
# column8 as TradePrice,
# column9 as TotalConsideration,
# column10 as SettlementCurrency,
# column11 as LusidInstrumentId,
# Column12 as TradeToPortfolioRate,
# column13 as ExchangeRate,
# 'abor' as Source
# from @transactions;
#
# -- Step 2: Load transactions into LUSID
#
# select *
# from Lusid.Portfolio.Txn.Writer
# where ToWrite = @createTransactions;
# Out:
#      PortfolioScope    PortfolioCode      DisplayName    TxnId       Type  \
# 0  tb-example-scope  tbAborPortfolio  tbAborPortfolio  csh_001    FundsIn
# 1  tb-example-scope  tbAborPortfolio  tbAborPortfolio  csh_002    FundsIn
# 2  tb-example-scope  tbAborPortfolio  tbAborPortfolio  csh_003   FundsOut
# 3  tb-example-scope  tbAborPortfolio  tbAborPortfolio  csh_004   FundsOut
# 4  tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_015  FxSpotBuy
# 5  tb-example-scope  tbAborPortfolio  tbAborPortfolio  txn_016  FxSpotBuy
#
#   TransactionDate SettlementDate    Units  TradePrice TradePriceType  ...  \
# 0      2023-01-01     2023-01-03  1000000           1          Price  ...
# 1      2023-01-01     2023-01-03  1000000           1          Price  ...
# 2      2023-02-01     2023-02-03   200000           1          Price  ...
# 3      2023-02-01     2023-02-03   200000           1          Price  ...
# 4      2023-02-15     2023-02-17   100000           1          Price  ...
# 5      2023-02-16     2023-02-18    50000           1          Price  ...
#
#    TxnPctProp  TxnDerivedDateProp  TxnAmountProp TxnCurrencyProp  \
# 0         NaN                 NaN            NaN             NaN
# 1         NaN                 NaN            NaN             NaN
# 2         NaN                 NaN            NaN             NaN
# 3         NaN                 NaN            NaN             NaN
# 4         NaN                 NaN            NaN             NaN
# 5         NaN                 NaN            NaN             NaN
#
#    ShareClassShortCode WriteAction                WriteAsAt  WriteErrorCode  \
# 0                  NaN      Upsert  2025-01-08 11:15:23.162               0
# 1                  NaN      Upsert  2025-01-08 11:15:23.162               0
# 2                  NaN      Upsert  2025-01-08 11:15:23.162               0
# 3                  NaN      Upsert  2025-01-08 11:15:23.162               0
# 4                  NaN      Upsert  2025-01-08 11:15:23.162               0
# 5                  NaN      Upsert  2025-01-08 11:15:23.162               0
#
#    WriteError  WriteErrorDetail
# 0         NaN               NaN
# 1         NaN               NaN
# 2         NaN               NaN
# 3         NaN               NaN
# 4         NaN               NaN
# 5         NaN               NaN
#
# [6 rows x 68 columns]

# %% [markdown]
# ## Create a chart of accounts
#
# Once the portfolio has been setup, we now move onto the ABOR setup. First we create a Chart of Accounts.

# %%
# %%luminesce
#
# /*
#
# --------------------------
# Create a Chart of Accounts
# --------------------------
#
# In this snippet we create a Chart of Accounts.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# */
#
# -- Step 1: Define the Chart of Accounts
#
# @@scope = select 'tb-example-scope';
# @@code = select 'tbChartOfAccounts';
# @@name = select 'TB Chart Of Accounts';
# @@writeAction = select 'Upsert';
#
# @chartOfAccounts =
# select
# @@scope as ChartOfAccountsScope,
# @@code as ChartOfAccountsCode,
# @@name as DisplayName,
# @@name as Description,
# @@writeAction as WriteAction;
#
# -- Step 2: Upload Chart of Account into LUSID
#
# select * from Lusid.ChartOfAccounts.Writer where ToWrite = @chartOfAccounts;
# Out:
#   ChartOfAccountsScope ChartOfAccountsCode           DisplayName  \
# 0     tb-example-scope   tbChartOfAccounts  TB Chart Of Accounts
#
#             Description  CoaStrProp  CoaTimeVarStrProp  CoaNumProp  \
# 0  TB Chart Of Accounts         NaN                NaN         NaN
#
#    CoaReqDateProp WriteAction                WriteAsAt  WriteErrorCode  \
# 0             NaN      Insert  2025-01-08 11:15:24.227               0
#
#    WriteError  WriteErrorDetail
# 0         NaN               NaN

# %% [markdown]
# ## Add accounts to chart of accounts
#
# Next we add some accounts to the Chart of Account.

# %%
# %%luminesce
#
# /*
#
# ---------------------------------
# Add Accounts to Chart of Accounts
# ---------------------------------
#
# In this snippet we add Accounts to a Chart of Accounts.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Setup a Chart of Accounts with the scope/code referenced below
#
# */
#
# -- Step 1: Define some accounts
#
# @@scope = select 'tb-example-scope';
# @@code = select 'tbChartOfAccounts';
#
# @accounts = values
# -- Investments
# ('A0001-Investments', 'Asset'),
#
# -- Cash, commitments
# ('A0002-Settled-Cash', 'Asset'),
#
# -- Sales and purchases for settlement
# ('A0003-Sales-To-Settle', 'Asset'),
# ('A0004-Purchases-To-Settle', 'Asset'),
# ('A0005-Long-FX-To-Settle', 'Asset'),
# ('A0006-Short-FX-To-Settle', 'Asset'),
#
# --Capital
# ('A0007-Capital', 'Asset'),
#
# -- Gains and Losses
# ('A0008-Realised-Market-Gains', 'Income'),
# ('A0009-Realised-Fx-Gains', 'Income'),
# ('A0010-UnrealisedGains', 'Income'),
#
# -- Subs, reds and accruals
# ('A0011-Accruals', 'Income'),
# ('A0012-Subscriptions', 'Asset'),
# ('A0013-Redemptions', 'Asset'),
#
# -- Unknown catch alls
# ('A0101-Unknown-NA',  'Asset'),
# ('A0102-Unknown-PL',  'Revenue'),
# ('A0103-Unknown-CA', 'Capital');
#
# @chartsOfAccountsAccounts = select
# @@scope as ChartOfAccountsScope,
# @@code as ChartOfAccountsCode,
# column1 as AccountCode,
# column1 as Description,
# column2 as Type,
# 'Manual' as Control,
# 'Active' as Status
# from @accounts;
#
# -- Step 2: Assign Accounts onto a ChartOfAccount
#
# select * from Lusid.ChartOfAccounts.Account.Writer
# where ToWrite = @chartsOfAccountsAccounts;
# Out:
#    ChartOfAccountsScope ChartOfAccountsCode                  AccountCode  \
# 0      tb-example-scope   tbChartOfAccounts            A0001-Investments
# 1      tb-example-scope   tbChartOfAccounts           A0002-Settled-Cash
# 2      tb-example-scope   tbChartOfAccounts        A0003-Sales-To-Settle
# 3      tb-example-scope   tbChartOfAccounts    A0004-Purchases-To-Settle
# 4      tb-example-scope   tbChartOfAccounts      A0005-Long-FX-To-Settle
# 5      tb-example-scope   tbChartOfAccounts     A0006-Short-FX-To-Settle
# 6      tb-example-scope   tbChartOfAccounts                A0007-Capital
# 7      tb-example-scope   tbChartOfAccounts  A0008-Realised-Market-Gains
# 8      tb-example-scope   tbChartOfAccounts      A0009-Realised-Fx-Gains
# 9      tb-example-scope   tbChartOfAccounts        A0010-UnrealisedGains
# 10     tb-example-scope   tbChartOfAccounts               A0011-Accruals
# 11     tb-example-scope   tbChartOfAccounts          A0012-Subscriptions
# 12     tb-example-scope   tbChartOfAccounts            A0013-Redemptions
# 13     tb-example-scope   tbChartOfAccounts             A0101-Unknown-NA
# 14     tb-example-scope   tbChartOfAccounts             A0102-Unknown-PL
# 15     tb-example-scope   tbChartOfAccounts             A0103-Unknown-CA
#
#                     Description     Type Control  Status  AccStrProp  \
# 0             A0001-Investments    Asset  Manual  Active         NaN
# 1            A0002-Settled-Cash    Asset  Manual  Active         NaN
# 2         A0003-Sales-To-Settle    Asset  Manual  Active         NaN
# 3     A0004-Purchases-To-Settle    Asset  Manual  Active         NaN
# 4       A0005-Long-FX-To-Settle    Asset  Manual  Active         NaN
# 5      A0006-Short-FX-To-Settle    Asset  Manual  Active         NaN
# 6                 A0007-Capital    Asset  Manual  Active         NaN
# 7   A0008-Realised-Market-Gains   Income  Manual  Active         NaN
# 8       A0009-Realised-Fx-Gains   Income  Manual  Active         NaN
# 9         A0010-UnrealisedGains   Income  Manual  Active         NaN
# 10               A0011-Accruals   Income  Manual  Active         NaN
# 11          A0012-Subscriptions    Asset  Manual  Active         NaN
# 12            A0013-Redemptions    Asset  Manual  Active         NaN
# 13             A0101-Unknown-NA    Asset  Manual  Active         NaN
# 14             A0102-Unknown-PL  Revenue  Manual  Active         NaN
# 15             A0103-Unknown-CA  Capital  Manual  Active         NaN
#
#     AccTimeVarStrProp  AccNumProp  AccBoolProp  AccReqDateProp WriteAction  \
# 0                 NaN         NaN          NaN             NaN      Upsert
# 1                 NaN         NaN          NaN             NaN      Upsert
# 2                 NaN         NaN          NaN             NaN      Upsert
# 3                 NaN         NaN          NaN             NaN      Upsert
# 4                 NaN         NaN          NaN             NaN      Upsert
# 5                 NaN         NaN          NaN             NaN      Upsert
# 6                 NaN         NaN          NaN             NaN      Upsert
# 7                 NaN         NaN          NaN             NaN      Upsert
# 8                 NaN         NaN          NaN             NaN      Upsert
# 9                 NaN         NaN          NaN             NaN      Upsert
# 10                NaN         NaN          NaN             NaN      Upsert
# 11                NaN         NaN          NaN             NaN      Upsert
# 12                NaN         NaN          NaN             NaN      Upsert
# 13                NaN         NaN          NaN             NaN      Upsert
# 14                NaN         NaN          NaN             NaN      Upsert
# 15                NaN         NaN          NaN             NaN      Upsert
#
#                   WriteAsAt  WriteErrorCode  WriteError  WriteErrorDetail
# 0   2025-01-08 11:15:25.264               0         NaN               NaN
# 1   2025-01-08 11:15:25.264               0         NaN               NaN
# 2   2025-01-08 11:15:25.264               0         NaN               NaN
# 3   2025-01-08 11:15:25.264               0         NaN               NaN
# 4   2025-01-08 11:15:25.264               0         NaN               NaN
# 5   2025-01-08 11:15:25.264               0         NaN               NaN
# 6   2025-01-08 11:15:25.264               0         NaN               NaN
# 7   2025-01-08 11:15:25.264               0         NaN               NaN
# 8   2025-01-08 11:15:25.264               0         NaN               NaN
# 9   2025-01-08 11:15:25.264               0         NaN               NaN
# 10  2025-01-08 11:15:25.264               0         NaN               NaN
# 11  2025-01-08 11:15:25.264               0         NaN               NaN
# 12  2025-01-08 11:15:25.264               0         NaN               NaN
# 13  2025-01-08 11:15:25.264               0         NaN               NaN
# 14  2025-01-08 11:15:25.264               0         NaN               NaN
# 15  2025-01-08 11:15:25.264               0         NaN               NaN

# %% [markdown]
# ## Create posting module
#
# Then we assign some posting rules to the Chart of Account which control how each JE line gets assigned to each account.

# %%
# %%luminesce
#
# /*
#
# ----------------------
# Create posting modules
# ----------------------
#
# In this snippet we create a posting module.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Setup a Chart of Accounts with the scope/code referenced below
#
# */
#
# -- Step 1: Define a posting module
#
# @@scope = select 'tb-example-scope';
# @@coaCode = select 'tbChartOfAccounts';
# @@postingModuleCode = select 'tbPostingModule';
# @@writeAction = select 'Upsert';
#
# @postingModule =
# select
# @@postingModuleCode as PostingModuleCode,
# @@coaCode as ChartOfAccountsCode,
# @@scope as ChartOfAccountsScope,
# 'Active' as Status,
# 'Daily NAV' as DisplayName,
# 'Posting module for daily NAV' as Description,
# @@writeAction as WriteAction;
#
# -- Step 2: Upload posting module into LUSID
#
# select * from Lusid.PostingModule.Writer where ToWrite = @postingModule;
# Out:
#   ChartOfAccountsScope ChartOfAccountsCode PostingModuleCode  \
# 0     tb-example-scope   tbChartOfAccounts   tbPostingModule
#
#                     Description DisplayName  Status WriteAction  \
# 0  Posting module for daily NAV   Daily NAV  Active      Upsert
#
#                  WriteAsAt  WriteErrorCode  WriteError  WriteErrorDetail
# 0  2025-01-08 11:15:26.055               0         NaN               NaN

# %% [markdown]
# ## Create posting rules

# %%
# %%luminesce
#
# /*
#
# --------------------
# Create posting rules
# --------------------
#
# In this snippet we create some posting rules.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Setup a Posting Module wuth the scope/code referenced below
#
#
# */
#
# -- Step 1: Define posting rules
#
# @@scope = select 'tb-example-scope';
# @@coaCode = select 'tbChartOfAccounts';
# @@postingModuleCode = select 'tbPostingModule';
#
# @rules_filters = values
# (
#     'Rule-001',
#     'EconomicBucket startswith ''NA''
#         and HoldType eq ''P''',
#     'A0001-Investments',
#     1
# ),
# (
#     'Rule-002',
#     'EconomicBucket startswith ''NA'' and HoldType eq ''B''',
#     'A0002-Settled-Cash',
#     2
# ),
# (
#     'Rule-003',
#     'EconomicBucket startswith ''NA_''
#         and MovementName eq ''CashProceeds''
#         and HoldType neq ''B''',
#     'A0003-Sales-To-Settle',
#     3
# ),
# (
#     'Rule-004',
#     'EconomicBucket startswith ''NA_''
#         and MovementName eq ''CashInvested''
#         and HoldType neq ''B''',
#     'A0004-Purchases-To-Settle',
#     4
# ),
# (
#     'Rule-005',
#     'EconomicBucket startswith ''NA_''
#         and MovementName eq ''FxSpotBuyLeg''
#         and HoldType neq ''B''',
#     'A0005-Long-FX-To-Settle',
#     5
# ),
# (
#     'Rule-006',
#     'EconomicBucket startswith ''NA_''
#         and MovementName eq ''FxSpotSellLeg''
#         and HoldType neq ''B''',
#     'A0006-Short-FX-To-Settle',
#     6
# ),
# (
#     'Rule-007',
#     'EconomicBucket eq ''CA_Capital''',
#     'A0007-Capital',
#     7
# ),
# (
#     'Rule-008',
#     'EconomicBucket eq ''PL_RealPriceGL'' and HoldType eq ''P''',
#     'A0008-Realised-Market-Gains',
#     8
# ),
# (
#     'Rule-009',
#     'EconomicBucket eq ''PL_RealFXGL'' and HoldType in ''P'', ''B''',
#     'A0009-Realised-Fx-Gains',
#     9
# ),
# (
#     'Rule-010',
#     'EconomicBucket startswith ''PL_Unreal''',
#     'A0010-UnrealisedGains',
#     10
# ),
# (
#     'Rule-011',
#     'EconomicBucket startswith ''PL_Accrued''',
#     'A0011-Accruals',
#     11
# ),
# (
#     'Rule-012',
#     'MovementName eq ''Subscription'' and HoldType neq ''B''',
#     'A0012-Subscriptions',
#     12
# ),
# (
#     'Rule-013',
#     'MovementName eq ''Redemption'' and HoldType neq ''B''',
#     'A0013-Redemptions',
#     13
# ),
# (
#     'Rule-101',
#     'EconomicBucket startswith ''NA''',
#     'A0101-Unknown-NA',
#     14
# ),
# (
#     'Rule-102',
#     'EconomicBucket startswith ''PL''',
#     'A0102-Unknown-PL',
#     15
# ),
# (
#     'Rule-103',
#     'EconomicBucket startswith ''CA''',
#     'A0103-Unknown-CA',
#     16
# )
# ;
#
#
# -- Step 2: Add posting rules to posting module
#
# @postingRules = select
# @@scope as ChartOfAccountsScope,
# @@coaCode as ChartOfAccountsCode,
# @@postingModuleCode as PostingModuleCode,
# column1 as RuleId,
# column2 as RuleFilter,
# column3 as GeneralLedgerAccountCode,
# column4 as RulePriority
# from @rules_filters;
#
# select * from Lusid.PostingModule.Rule.Writer where ToWrite = @postingRules;
# Out:
#    ChartOfAccountsScope ChartOfAccountsCode PostingModuleCode  RulePriority  \
# 0      tb-example-scope   tbChartOfAccounts   tbPostingModule             1
# 1      tb-example-scope   tbChartOfAccounts   tbPostingModule             2
# 2      tb-example-scope   tbChartOfAccounts   tbPostingModule             3
# 3      tb-example-scope   tbChartOfAccounts   tbPostingModule             4
# 4      tb-example-scope   tbChartOfAccounts   tbPostingModule             5
# 5      tb-example-scope   tbChartOfAccounts   tbPostingModule             6
# 6      tb-example-scope   tbChartOfAccounts   tbPostingModule             7
# 7      tb-example-scope   tbChartOfAccounts   tbPostingModule             8
# 8      tb-example-scope   tbChartOfAccounts   tbPostingModule             9
# 9      tb-example-scope   tbChartOfAccounts   tbPostingModule            10
# 10     tb-example-scope   tbChartOfAccounts   tbPostingModule            11
# 11     tb-example-scope   tbChartOfAccounts   tbPostingModule            12
# 12     tb-example-scope   tbChartOfAccounts   tbPostingModule            13
# 13     tb-example-scope   tbChartOfAccounts   tbPostingModule            14
# 14     tb-example-scope   tbChartOfAccounts   tbPostingModule            15
# 15     tb-example-scope   tbChartOfAccounts   tbPostingModule            16
#
#       RuleId     GeneralLedgerAccountCode  \
# 0   Rule-001            A0001-Investments
# 1   Rule-002           A0002-Settled-Cash
# 2   Rule-003        A0003-Sales-To-Settle
# 3   Rule-004    A0004-Purchases-To-Settle
# 4   Rule-005      A0005-Long-FX-To-Settle
# 5   Rule-006     A0006-Short-FX-To-Settle
# 6   Rule-007                A0007-Capital
# 7   Rule-008  A0008-Realised-Market-Gains
# 8   Rule-009      A0009-Realised-Fx-Gains
# 9   Rule-010        A0010-UnrealisedGains
# 10  Rule-011               A0011-Accruals
# 11  Rule-012          A0012-Subscriptions
# 12  Rule-013            A0013-Redemptions
# 13  Rule-101             A0101-Unknown-NA
# 14  Rule-102             A0102-Unknown-PL
# 15  Rule-103             A0103-Unknown-CA
#
#                                            RuleFilter  \
# 0   EconomicBucket startswith 'NA' \n        and H...
# 1   EconomicBucket startswith 'NA' and HoldType eq...
# 2   EconomicBucket startswith 'NA_' \n        and ...
# 3   EconomicBucket startswith 'NA_' \n        and ...
# 4   EconomicBucket startswith 'NA_' \n        and ...
# 5   EconomicBucket startswith 'NA_' \n        and ...
# 6                      EconomicBucket eq 'CA_Capital'
# 7   EconomicBucket eq 'PL_RealPriceGL' and HoldTyp...
# 8   EconomicBucket eq 'PL_RealFXGL' and HoldType i...
# 9               EconomicBucket startswith 'PL_Unreal'
# 10             EconomicBucket startswith 'PL_Accrued'
# 11  MovementName eq 'Subscription' and HoldType ne...
# 12  MovementName eq 'Redemption' and HoldType neq 'B'
# 13                     EconomicBucket startswith 'NA'
# 14                     EconomicBucket startswith 'PL'
# 15                     EconomicBucket startswith 'CA'
#
#                   WriteAsAt  WriteErrorCode  WriteError  WriteErrorDetail
# 0   2025-01-08 11:15:26.961               0         NaN               NaN
# 1   2025-01-08 11:15:26.961               0         NaN               NaN
# 2   2025-01-08 11:15:26.961               0         NaN               NaN
# 3   2025-01-08 11:15:26.961               0         NaN               NaN
# 4   2025-01-08 11:15:26.961               0         NaN               NaN
# 5   2025-01-08 11:15:26.961               0         NaN               NaN
# 6   2025-01-08 11:15:26.961               0         NaN               NaN
# 7   2025-01-08 11:15:26.961               0         NaN               NaN
# 8   2025-01-08 11:15:26.961               0         NaN               NaN
# 9   2025-01-08 11:15:26.961               0         NaN               NaN
# 10  2025-01-08 11:15:26.961               0         NaN               NaN
# 11  2025-01-08 11:15:26.961               0         NaN               NaN
# 12  2025-01-08 11:15:26.961               0         NaN               NaN
# 13  2025-01-08 11:15:26.961               0         NaN               NaN
# 14  2025-01-08 11:15:26.961               0         NaN               NaN
# 15  2025-01-08 11:15:26.961               0         NaN               NaN

# %% [markdown]
# ## Create an abor configuration
#
# Next we create an Abor Configuration which binds a Chart of Accounts (with Posting Rules) to a given recipe.

# %%
# %%luminesce
#
# /*
#
# ----------------------------
# Create an ABOR configuration
# ----------------------------
#
# In this snippet we create an ABOR Configurtion.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Setup Chart of Accounts referenced below
#     2. Setup a Posting Module wuth the scope/code referenced below
#     3. Setup the recipe referenced below
#
#
# */
#
# @@scope = select 'tb-example-scope';
# @@chartOfAccountsCode = select 'tbChartOfAccounts';
# @@code = select 'tbAborConfiguration';
# @@writeAction = select 'Insert';
# @@PostingModuleCodes = select 'tbPostingModule';
#
# -- Step 1: Create an ABOR configuration
#
# @aborConfigurationForUpload = select
# @@code as AborConfigurationCode,
# @@scope as AborConfigurationScope,
# @@code as Description,
# @@chartOfAccountsCode as ChartOfAccountsCode,
# @@scope as ChartOfAccountsScope,
# @@PostingModuleCodes as PostingModuleCodes,
# @@code as DisplayName,
# @@scope as RecipeScope,
# 'marketValue' as RecipeCode,
# @@writeAction as WriteAction;
#
# -- Step 2: Load ABOR configurtion into LUSID
#
# select * from Lusid.AborConfiguration.Writer
# where ToWrite = @aborConfigurationForUpload;
# Out:
#   AborConfigurationScope AborConfigurationCode       RecipeScope   RecipeCode  \
# 0       tb-example-scope   tbAborConfiguration  tb-example-scope  marketValue
#
#            DisplayName ChartOfAccountsScope ChartOfAccountsCode  \
# 0  tbAborConfiguration     tb-example-scope   tbChartOfAccounts
#
#            Description PostingModuleCodes  CleardownModuleCodes  \
# 0  tbAborConfiguration    tbPostingModule                   NaN
#
#    AborConfigStrProp  AborConfigTimeVarStrProp  AborConfigNumProp  \
# 0                NaN                       NaN                NaN
#
#    AborConfigReqDateProp WriteAction                WriteAsAt  WriteErrorCode  \
# 0                    NaN      Insert  2025-01-08 11:15:27.707               0
#
#    WriteError  WriteErrorDetail
# 0         NaN               NaN

# %% [markdown]
# ## Create abor
#
# We also create an ABOR which binds an AborConfiguration to a given portfolio.

# %%
# %%luminesce
#
# /*
#
# --------------
# Create an ABOR
# --------------
#
# In this snippet we create an ABOR.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Setup Abor Configuration referenced below
#     2. Setup portfolio referenced below
#
#
# */
#
# @@scope = select 'tb-example-scope';
# @@code = select 'tbAbor';
# @@aborConfigCode = select 'tbAborConfiguration';
# @@portfolioCode = select 'tbAborPortfolio';
# @@writeAction = select 'Upsert';
#
# -- Step 1: Define an ABOR
#
# @aborForUpload = select
# @@scope as AborScope,
# @@code as AborCode,
# @@code as DisplayName,
# 'SinglePortfolio' as PortfolioEntityType,
# @@scope  as PortfolioScope,
# @@portfolioCode as PortfolioCode,
# @@portfolioCode as Description,
# @@scope  as AborConfigurationScope,
# @@aborConfigCode as AborConfigurationCode,
# @@writeAction as WriteAction;
#
# -- Step 2: Load ABOR into LUSID
#
# select * from Lusid.Abor.Writer
# where ToWrite = @aborForUpload
# Out:
#           AborScope AborCode PortfolioEntityType    PortfolioScope  \
# 0  tb-example-scope   tbAbor     SinglePortfolio  tb-example-scope
#
#      PortfolioCode DisplayName      Description AborConfigurationScope  \
# 0  tbAborPortfolio      tbAbor  tbAborPortfolio       tb-example-scope
#
#   AborConfigurationCode  AbStrProp  AbTimeVarStrProp  AbNumProp  \
# 0   tbAborConfiguration        NaN               NaN        NaN
#
#    AbReqDateProp WriteAction                WriteAsAt  WriteErrorCode  \
# 0            NaN      Insert  2025-01-08 11:15:28.737               0
#
#    WriteError  WriteErrorDetail
# 0         NaN               NaN

# %% [markdown]
# ## Create journal entry lines
#
# We can then run some JE (Journal Entry) lines against the ABOR.

# %%
# %%luminesce
#
# /*
#
# -------------------------------
# Create Journal Entry (JE) Lines
# -------------------------------
#
# In this snippet we create an ABOR.
#
# For more details on LUSID providers, see this page:
#
# https://support.lusid.com/knowledgebase/category/?id=CAT-01099
#
# Prerequisite setup steps:
#
#     1. Create the ABOR referenced below
#
#
# */
#
# @@scope = select 'tb-example-scope';
# @@code = select 'tbAbor';
#
# --Step 1: Generate JE Lines
#
# select * from Lusid.Abor.JELine
# where AborScope = @@scope
# and AborCode = @@code
# and StartDate = '2023-01-02'
# and EndDate = '2023-03-03';
# Out:
#             AborScope AborCode    PortfolioScope    PortfolioCode  \
# 0    tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# 1    tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# 2    tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# 3    tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# 4    tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# ..                ...      ...               ...              ...
# 139  tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# 140  tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# 141  tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# 142  tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
# 143  tb-example-scope   tbAbor  tb-example-scope  tbAborPortfolio
#
#     AccountingDate ActivityDate                     GlCode        SourceType  \
# 0       2023-01-03   2023-01-03         A0002-Settled-Cash  LusidTransaction
# 1       2023-01-03   2023-01-03  A0004-Purchases-To-Settle  LusidTransaction
# 2       2023-01-03   2023-01-03         A0002-Settled-Cash  LusidTransaction
# 3       2023-01-03   2023-01-03  A0004-Purchases-To-Settle  LusidTransaction
# 4       2023-01-03   2023-01-03         A0002-Settled-Cash  LusidTransaction
# ..             ...          ...                        ...               ...
# 139     2023-03-03   2023-03-03      A0010-UnrealisedGains    LusidValuation
# 140     2023-03-03   2023-03-03          A0001-Investments    LusidValuation
# 141     2023-03-03   2023-03-03             A0011-Accruals    LusidValuation
# 142     2023-03-03   2023-03-03         A0002-Settled-Cash    LusidValuation
# 143     2023-03-03   2023-03-03      A0010-UnrealisedGains    LusidValuation
#
#                               SourceId   InstrumentId  ... SourceLevel1  \
# 0                              txn_001        CCY_GBP  ...          NaN
# 1                              txn_001        CCY_GBP  ...          NaN
# 2                              txn_002        CCY_GBP  ...          NaN
# 3                              txn_002        CCY_GBP  ...          NaN
# 4                              txn_003        CCY_USD  ...          NaN
# ..                                 ...            ...  ...          ...
# 139  2023-03-03T00:00:00.0000000+00:00  LUID_000CVCKG  ...          NaN
# 140  2023-03-03T00:00:00.0000000+00:00  LUID_000CVCKG  ...          NaN
# 141  2023-03-03T00:00:00.0000000+00:00  LUID_000CVCKG  ...          NaN
# 142  2023-03-03T00:00:00.0000000+00:00        CCY_USD  ...          NaN
# 143  2023-03-03T00:00:00.0000000+00:00        CCY_USD  ...          NaN
#
#      SourceLevel2 SourceLevel3  SourceLevel4 SourceLevel5  MovementSign  \
# 0             NaN          NaN           NaN          NaN         Short
# 1             NaN          NaN           NaN          NaN          Long
# 2             NaN          NaN           NaN          NaN         Short
# 3             NaN          NaN           NaN          NaN          Long
# 4             NaN          NaN           NaN          NaN         Short
# ..            ...          ...           ...          ...           ...
# 139           NaN          NaN           NaN          NaN          Long
# 140           NaN          NaN           NaN          NaN          Long
# 141           NaN          NaN           NaN          NaN          Long
# 142           NaN          NaN           NaN          NaN          Long
# 143           NaN          NaN           NaN          NaN          Long
#
#     HoldingSign JournalEntryLineType Error TxnStrProp
# 0         Short              Default   NaN        NaN
# 1         Short              Default   NaN        NaN
# 2         Short              Default   NaN        NaN
# 3         Short              Default   NaN        NaN
# 4         Short              Default   NaN        NaN
# ..          ...                  ...   ...        ...
# 139        Long              Default   NaN        NaN
# 140        Long              Default   NaN        NaN
# 141        Long              Default   NaN        NaN
# 142        Long              Default   NaN        NaN
# 143        Long              Default   NaN        NaN
#
# [144 rows x 40 columns]

# %% [markdown]
# ## General ledger profile
#
# Create a General Ledger profile.

# %%
# %%luminesce
#
# @@scope = select 'tb-example-scope';
# @@chartOfAccountsCode = select 'tbChartOfAccounts';
# @@generalLedgerProfileCode = select 'tbGeneralLedgerProfile';
#
# @glProfile = select
# @@scope as ChartOfAccountsScope,
# @@chartOfAccountsCode as ChartOfAccountsCode,
# @@chartOfAccountsCode as DisplayName,
# @@generalLedgerProfileCode as GeneralLedgerProfileCode,
# 'Insert' as WriteAction
# ;
#
# select * from Lusid.GeneralLedgerProfile.Writer
# where ToWrite = @glProfile;
# Out:
#   ChartOfAccountsScope ChartOfAccountsCode GeneralLedgerProfileCode  \
# 0     tb-example-scope   tbChartOfAccounts   tbGeneralLedgerProfile
#
#    Description        DisplayName WriteAction                WriteAsAt  \
# 0          NaN  tbChartOfAccounts      Insert  2025-01-08 11:15:35.443
#
#    WriteErrorCode  WriteError  WriteErrorDetail
# 0               0         NaN               NaN

# %% [markdown]
# ## General Ledger Profile mapppings
#
# Add some mappings to the General Ledger Profile.

# %%
# %%luminesce
#
# @@scope = select 'tb-example-scope';
# @@chartOfAccountsCode = select 'tbChartOfAccounts';
# @@generalLedgerProfileCode = select 'tbGeneralLedgerProfile';
#
#
# @mappings = values
# (
#     'GeneralLedgerAccountCode eq ''A0001-Investments''',
#     'DefaultCurrency',
#     'Properties[Instrument/tb-example-scope/AssetClass]',
#     '',
#     1
# ),
# (
#     'GeneralLedgerAccountCode eq ''A0002-Settled-Cash''',
#     'DefaultCurrency',
#     Null,
#     '',
#     2
# ),
# (
#     'GeneralLedgerAccountCode eq ''A0003-Sales-To-Settle''',
#     'DefaultCurrency',
#     Null,
#     '',
#     3
# ),
# (
#     'GeneralLedgerAccountCode eq ''A0004-Purchases-To-Settle''',
#     'DefaultCurrency',
#     Null,
#     '',
#     4
# ),
# (
#     'GeneralLedgerAccountCode eq ''A0010-UnrealisedGains''',
#     'DefaultCurrency',
#     Null,
#     '',
#     5
# )
# ;
#
# @mappingsToWrite = select
# @@chartOfAccountsCode as ChartOfAccountsCode,
# @@scope as ChartOfAccountsScope,
# @@generalLedgerProfileCode as GeneralLedgerProfileCode,
# column1 as MappingFilter,
# column2 as Level1,
# column3 as Level2,
# column5 as MappingPriority
# from @mappings;
#
# select * from Lusid.GeneralLedgerProfile.Mapping.Writer
# where ToWrite = @mappingsToWrite;
# Out:
#   ChartOfAccountsScope ChartOfAccountsCode GeneralLedgerProfileCode  \
# 0     tb-example-scope   tbChartOfAccounts   tbGeneralLedgerProfile
# 1     tb-example-scope   tbChartOfAccounts   tbGeneralLedgerProfile
# 2     tb-example-scope   tbChartOfAccounts   tbGeneralLedgerProfile
# 3     tb-example-scope   tbChartOfAccounts   tbGeneralLedgerProfile
# 4     tb-example-scope   tbChartOfAccounts   tbGeneralLedgerProfile
#
#    MappingPriority                                      MappingFilter  \
# 0                1    GeneralLedgerAccountCode eq 'A0001-Investments'
# 1                2   GeneralLedgerAccountCode eq 'A0002-Settled-Cash'
# 2                3  GeneralLedgerAccountCode eq 'A0003-Sales-To-Se...
# 3                4  GeneralLedgerAccountCode eq 'A0004-Purchases-T...
# 4                5  GeneralLedgerAccountCode eq 'A0010-UnrealisedG...
#
#             Level1                                             Level2  Level3  \
# 0  DefaultCurrency  Properties[Instrument/tb-example-scope/AssetCl...     NaN
# 1  DefaultCurrency                                                NaN     NaN
# 2  DefaultCurrency                                                NaN     NaN
# 3  DefaultCurrency                                                NaN     NaN
# 4  DefaultCurrency                                                NaN     NaN
#
#    Level4  Level5                WriteAsAt  WriteErrorCode  WriteError  \
# 0     NaN     NaN  2025-01-08 11:15:37.006               0         NaN
# 1     NaN     NaN  2025-01-08 11:15:37.006               0         NaN
# 2     NaN     NaN  2025-01-08 11:15:37.006               0         NaN
# 3     NaN     NaN  2025-01-08 11:15:37.006               0         NaN
# 4     NaN     NaN  2025-01-08 11:15:37.006               0         NaN
#
#    WriteErrorDetail
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# ## Generate a Trial Balance
#
# Now we can generate a Trial Balance

# %%
# %%luminesce
#
# select
# GeneralLedgerProfileAccountCode,
# Level1,
# Level2,
# AccountType,
# Opening,
# Closing,
# Debit,
# Credit
# from Lusid.Abor.TrialBalance
# where StartDate = '2023-01-02'
# and EndDate = '2023-03-03'
# and AborScope = 'tb-example-scope'
# and AborCode = 'tbAbor'
# and GeneralLedgerProfileCode = 'tbGeneralLedgerProfile'
# order by GeneralLedgerProfileAccountCode
# Out:
#    GeneralLedgerProfileAccountCode               Level1           Level2  \
# 0                A0001-Investments                  GBP     Common Stock
# 1                A0001-Investments                  USD     Common Stock
# 2                A0001-Investments                  USD  Government Bond
# 3                A0001-Investments                  GBP  Government Bond
# 4               A0002-Settled-Cash                  GBP              NaN
# 5               A0002-Settled-Cash                  USD              NaN
# 6            A0003-Sales-To-Settle                  GBP              NaN
# 7            A0003-Sales-To-Settle                  USD              NaN
# 8        A0004-Purchases-To-Settle                  GBP              NaN
# 9        A0004-Purchases-To-Settle                  USD              NaN
# 10         A0005-Long-FX-To-Settle  No matching mapping              NaN
# 11        A0006-Short-FX-To-Settle  No matching mapping              NaN
# 12                   A0007-Capital  No matching mapping              NaN
# 13     A0008-Realised-Market-Gains  No matching mapping              NaN
# 14         A0009-Realised-Fx-Gains  No matching mapping              NaN
# 15           A0010-UnrealisedGains                  GBP              NaN
# 16           A0010-UnrealisedGains                  USD              NaN
# 17                  A0011-Accruals  No matching mapping              NaN
# 18             A0012-Subscriptions  No matching mapping              NaN
# 19               A0013-Redemptions  No matching mapping              NaN
#
#    AccountType     Opening     Closing       Debit      Credit
# 0        Asset   264077.89   167791.95   117791.95  -214077.89
# 1        Asset   198898.73   136897.36    96897.36  -158898.73
# 2        Asset    89574.03    42640.92     2640.92   -49574.03
# 3        Asset   213735.66   107573.00     7573.00  -113735.66
# 4        Asset        0.00   568000.00  1168000.00  -600000.00
# 5        Asset        0.00   708952.41  1002743.13  -293790.72
# 6        Asset        0.00        0.00   168000.00  -168000.00
# 7        Asset        0.00        0.00    75660.00   -75660.00
# 8        Asset  -280000.00        0.00   280000.00        0.00
# 9        Asset  -145095.07        0.00   145095.07        0.00
# 10       Asset        0.00        0.00   120000.00  -120000.00
# 11       Asset        0.00        0.00   120000.00  -120000.00
# 12       Asset -1790000.00 -1428000.00   362000.00        0.00
# 13      Income        0.00   -59060.00      540.00   -59600.00
# 14      Income        0.00    -4509.28     1400.00    -5909.28
# 15      Income  -197813.55  -124871.80   197813.55  -124871.80
# 16      Income  -206878.09  -114655.64   215973.16  -123750.71
# 17      Income        0.00     -758.92        0.00     -758.92
# 18       Asset  1853500.40        0.00        0.00 -1853500.40
# 19       Asset        0.00        0.00   362000.00  -362000.00

# %% [markdown]
# ## Run a check
#
# In the query below, we verify that the sum of Credits is equal the sum of the Debits.

# %%
# %%luminesce
#
# @tb = select sum(Debit) as SumDebits, sum(Credit) as SumCredits from Lusid.Abor.TrialBalance
# where GeneralLedgerProfileCode = 'tbGeneralLedgerProfile'
# and StartDate = '2023-01-02'
# and EndDate = '2023-03-03'
# and AborScope = 'tb-example-scope';
#
# select SumDebits, SumCredits, round((SumDebits + SumCredits), 2) as [Check] from @tb;
# Out:
#     SumDebits  SumCredits  Check
# 0  4444128.14 -4444128.14      0
